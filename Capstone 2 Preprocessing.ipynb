# %%
# Import relevant libraries and packages.
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split

# %%
# Load the data
stellar = pd.read_csv(r"C:\Users\maxsu\Capstone 2\star_classification.csv")

# %%
#First look at data
stellar.head()
# Out:
#          obj_ID       alpha      delta         u         g         r  \
# 0  1.237661e+18  135.689107  32.494632  23.87882  22.27530  20.39501
# 1  1.237665e+18  144.826101  31.274185  24.77759  22.83188  22.58444
# 2  1.237661e+18  142.188790  35.582444  25.26307  22.66389  20.60976
# 3  1.237663e+18  338.741038  -0.402828  22.13682  23.77656  21.61162
# 4  1.237680e+18  345.282593  21.183866  19.43718  17.58028  16.49747
#
#           i         z  run_ID  rerun_ID  cam_col  field_ID   spec_obj_ID  \
# 0  19.16573  18.79371    3606       301        2        79  6.543777e+18
# 1  21.16812  21.61427    4518       301        5       119  1.176014e+19
# 2  19.34857  18.94827    3606       301        2       120  5.152200e+18
# 3  20.50454  19.25010    4192       301        3       214  1.030107e+19
# 4  15.97711  15.54461    8102       301        3       137  6.891865e+18
#
#     class  redshift  plate    MJD  fiber_ID
# 0  GALAXY  0.634794   5812  56354       171
# 1  GALAXY  0.779136  10445  58158       427
# 2  GALAXY  0.644195   4576  55592       299
# 3  GALAXY  0.932346   9149  58039       775
# 4  GALAXY  0.116123   6121  56187       842

# %%
#Checking for any missing values
stellar.isnull().sum()
# Out:
# obj_ID         0
# alpha          0
# delta          0
# u              0
# g              0
# r              0
# i              0
# z              0
# run_ID         0
# rerun_ID       0
# cam_col        0
# field_ID       0
# spec_obj_ID    0
# class          0
# redshift       0
# plate          0
# MJD            0
# fiber_ID       0
# dtype: int64

# %%
#Datatypes of each column
stellar.dtypes
# Out:
# obj_ID         float64
# alpha          float64
# delta          float64
# u              float64
# g              float64
# r              float64
# i              float64
# z              float64
# run_ID           int64
# rerun_ID         int64
# cam_col          int64
# field_ID         int64
# spec_obj_ID    float64
# class           object
# redshift       float64
# plate            int64
# MJD              int64
# fiber_ID         int64
# dtype: object

# %%
#Checking the counts for each class
stellar['class'].value_counts()
# Out:
# GALAXY    59445
# STAR      21594
# QSO       18961
# Name: class, dtype: int64

# %%
#Checking dimensionality of dataframe
stellar.shape
# Out:
# (100000, 18)

# %%
#Dropping Object_ID
stellar.drop(['obj_ID'], axis = 1, inplace = True)
stellar.head()
# Out:
#         alpha      delta         u         g         r         i         z  \
# 0  135.689107  32.494632  23.87882  22.27530  20.39501  19.16573  18.79371
# 1  144.826101  31.274185  24.77759  22.83188  22.58444  21.16812  21.61427
# 2  142.188790  35.582444  25.26307  22.66389  20.60976  19.34857  18.94827
# 3  338.741038  -0.402828  22.13682  23.77656  21.61162  20.50454  19.25010
# 4  345.282593  21.183866  19.43718  17.58028  16.49747  15.97711  15.54461
#
#    run_ID  rerun_ID  cam_col  field_ID   spec_obj_ID   class  redshift  plate  \
# 0    3606       301        2        79  6.543777e+18  GALAXY  0.634794   5812
# 1    4518       301        5       119  1.176014e+19  GALAXY  0.779136  10445
# 2    3606       301        2       120  5.152200e+18  GALAXY  0.644195   4576
# 3    4192       301        3       214  1.030107e+19  GALAXY  0.932346   9149
# 4    8102       301        3       137  6.891865e+18  GALAXY  0.116123   6121
#
#      MJD  fiber_ID
# 0  56354       171
# 1  58158       427
# 2  55592       299
# 3  58039       775
# 4  56187       842

# %%
#Min value for each column
pd.DataFrame(stellar.values.min(0)[None, :], columns=stellar.columns)
# Out:
#       alpha      delta       u       g        r         i       z run_ID  \
# 0  0.005528 -18.785328 -9999.0 -9999.0  9.82207  9.469903 -9999.0    109
#
#   rerun_ID cam_col field_ID           spec_obj_ID   class  redshift plate  \
# 0      301       1       11  299519089380976640.0  GALAXY -0.009971   266
#
#      MJD fiber_ID
# 0  51608        1

# %%
#Max value for each column
pd.DataFrame(stellar.values.max(0)[None, :], columns=stellar.columns)
# Out:
#        alpha      delta         u         g         r         i         z  \
# 0  359.99981  83.000519  32.78139  31.60224  29.57186  32.14147  29.38374
#
#   run_ID rerun_ID cam_col field_ID             spec_obj_ID class  redshift  \
# 0   8162      301       6      989  14126940609093851136.0  STAR  7.011245
#
#    plate    MJD fiber_ID
# 0  12547  58932     1000

# %%
#Looking at the remaining 17 variables we can eliminate quite a few of them outright as they describe the equipment ID's run Id's, etc...
stellar = stellar.drop(columns = ['run_ID', 'rerun_ID', 'cam_col', 'field_ID', 'spec_obj_ID', 'fiber_ID', 'plate', 'MJD'])
stellar.head()
# Out:
#         alpha      delta         u         g         r         i         z  \
# 0  135.689107  32.494632  23.87882  22.27530  20.39501  19.16573  18.79371
# 1  144.826101  31.274185  24.77759  22.83188  22.58444  21.16812  21.61427
# 2  142.188790  35.582444  25.26307  22.66389  20.60976  19.34857  18.94827
# 3  338.741038  -0.402828  22.13682  23.77656  21.61162  20.50454  19.25010
# 4  345.282593  21.183866  19.43718  17.58028  16.49747  15.97711  15.54461
#
#     class  redshift
# 0  GALAXY  0.634794
# 1  GALAXY  0.779136
# 2  GALAXY  0.644195
# 3  GALAXY  0.932346
# 4  GALAXY  0.116123

# %%
#DATA VISUALIZATION

# %%
#Histogram of value counts
sns.histplot(data = stellar, x = 'class')
# Out:
# <Axes: xlabel='class', ylabel='Count'>

# %%
#Heatmap of the correlation between variables
import seaborn as sns
import matplotlib.pyplot as plt
fig,ax=plt.subplots(1,1,figsize=(20,12))
sns.heatmap(stellar.corr(),annot=True,linewidths=1)
plt.show()
# Out:
# C:\Users\maxsu\AppData\Local\Temp\ipykernel_3428\3726523046.py:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(stellar.corr(),annot=True,linewidths=1)

# %%
#From this map I am choosing ('u', 'g', 'r', 'i', 'z', 'redshift') as the features to use in my model so I will drop the rest
stellar = stellar.drop(columns= ['alpha', 'delta'])
stellar.head()
# Out:
#           u         g         r         i         z   class  redshift
# 0  23.87882  22.27530  20.39501  19.16573  18.79371  GALAXY  0.634794
# 1  24.77759  22.83188  22.58444  21.16812  21.61427  GALAXY  0.779136
# 2  25.26307  22.66389  20.60976  19.34857  18.94827  GALAXY  0.644195
# 3  22.13682  23.77656  21.61162  20.50454  19.25010  GALAXY  0.932346
# 4  19.43718  17.58028  16.49747  15.97711  15.54461  GALAXY  0.116123

# %%
#Since I will be using the 'class' variable as my 'y' in the modellingand 
#since their are no other categorical features I won't be doing any one-hot 
#encoding or obtaining any dummy variables

# %%
x =  stellar.drop(['class'], axis = 1)
Y = stellar['class'].values
x_train,x_test,Y_train,Y_test = train_test_split(x , Y , test_size=0.2 , random_state=0)
print('x_train', x_train.shape)
print('x_test', x_test.shape)
print('y_train', Y_train.shape)
print('y_test', Y_test.shape)
# Out:
# x_train (80000, 6)
# x_test (20000, 6)
# y_train (80000,)
# y_test (20000,)
